# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from numpy import genfromtxt
data1 = genfromtxt('data1.csv', delimiter=',')
X = data1[:,:-1]
y = data1[:, -1]
print(X.shape)
# Out:
# (60, 50)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
Xpca = pca.transform(X)

plt.figure()
plt.scatter(Xpca[:,0], Xpca[:,1], c=y)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
ypred = kmeans.predict(X)
print(ypred)
print(y)
plt.scatter(Xpca[:,0], Xpca[:,1], c=ypred)
# Out:
# [1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#  2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0]
# [1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3.
#  1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3.
#  1. 2. 3. 1. 2. 3. 1. 2. 3. 1. 2. 3.]

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
ypred = kmeans.predict(X)
plt.scatter(Xpca[:,0], Xpca[:,1], c=ypred)

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X)
ypred = kmeans.predict(X)
plt.scatter(Xpca[:,0], Xpca[:,1], c=ypred)

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(Xpca)
ypred = kmeans.predict(Xpca)
plt.scatter(Xpca[:,0], Xpca[:,1], c=ypred)

# %%
data2 = genfromtxt('data2.csv', delimiter=',')
plt.scatter(data2[:,0], data2[:,1])

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(data2, 'average')
dn = dendrogram(Z)

# %%
Z = linkage(data2, 'single')
dn = dendrogram(Z)

# %%
Z = linkage(data2, 'complete')
dn = dendrogram(Z)

# %%
X = data2
print(X.shape)
X = np.repeat(X[None, :, :], X.shape[0],axis=0)
X_T = X.transpose(1,0,2)

d = ((X - X_T)**2).sum(axis=2)
tri_upper_diag = np.triu(d, k=0)
plt.imshow(tri_upper_diag)
# Out:
# (50, 2)
